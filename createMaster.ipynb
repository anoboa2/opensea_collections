# %%
import os
import pandas as pd
import numpy as np

# %%
master_collections = pd.DataFrame(columns=['Symbol', 'Attribute', 'Trait', 'Count', 'Trait_Frequency', 'Trait_Rank', 'Overall_Frequency', 'Overall_Rank', 'Attribute_Frequency', 'Attribute_std_dev', 'Rarity_Score'])

# %%
path, dirs, files = next(os.walk("distributions"))

for f in files:
    df = pd.read_csv('distributions/'+f, index_col=0)
    master_collections = master_collections.append(df, ignore_index=True)

master_collections
# Out:
#           Symbol Attribute          Trait Count  Trait_Frequency  Trait_Rank  \
# 0     DEADFELLAZ      Nose     nose skull  2473         0.247300         7.0
# 1     DEADFELLAZ      Nose           ring     1         0.000100         1.0
# 2     DEADFELLAZ      Nose    nose normal  2052         0.205200         6.0
# 3     DEADFELLAZ      Nose      nose ring  2004         0.200400         5.0
# 4     DEADFELLAZ      Nose         normal     2         0.000200         2.0
# ...          ...       ...            ...   ...              ...         ...
# 5687      SEVENS      Hair     orange-red  1393         0.200201         4.0
# 5688      SEVENS      Hair          black  1392         0.200057         3.0
# 5689      SEVENS     Shape   square frame  2319         0.333285         2.0
# 5690      SEVENS     Shape   circle frame  2316         0.332854         1.0
# 5691      SEVENS     Shape  minimal frame  2323         0.333860         3.0
#
#       Overall_Frequency Overall_Rank  Attribute_Frequency  Attribute_std_dev  \
# 0              0.247374          118             0.059259           0.099079
# 1              0.000100            2             0.059259           0.099079
# 2              0.205262          117             0.059259           0.099079
# 3              0.200460          116             0.059259           0.099079
# 4              0.000200            6             0.059259           0.099079
# ...                 ...          ...                  ...                ...
# 5687           0.199028          173             0.027624           0.000215
# 5688           0.198886          171             0.027624           0.000215
# 5689           0.331333          177             0.016575           0.000412
# 5690           0.330904          176             0.016575           0.000412
# 5691           0.331905          178             0.016575           0.000412
#
#       Rarity_Score
# 0     3.625223e-03
# 1     5.927704e-10
# 2     2.495981e-03
# 3     2.380576e-03
# 4     2.371082e-09
# ...            ...
# 5687  1.100711e-03
# 5688  1.099131e-03
# 5689  1.830306e-03
# 5690  1.825574e-03
# 5691  1.836626e-03
#
# [5692 rows x 11 columns]

# %%
master_collections.to_csv('master_distribution.csv')

# %%
master_collections.value_counts('Symbol')
# Out:
# Symbol
# ⚇             1070
# DAD            489
# MAYC           345
# DOODLE         265
# COOL           252
# CREATURE       251
# TOADZ          246
# ROBO           243
# MEKA           242
# SD             225
# SVS            205
# DOGGY          193
# WOW            189
# SEVENS         181
# BAKC           177
# PPG            174
# LION           173
# BAYC           168
# HMNDS          152
# KONGZ          139
# DEADFELLAZ     135
# PUNK            92
# NEOTI           86
# dtype: int64
